# %% [markdown]
# # Demonstrating the effect of low mesh resolution on line profiles
#
# This notebook demonstrates how using a low-resolution mesh to model a rotating star's surface can affect the accuracy of simulated spectral line profiles. By comparing results from models with different numbers of surface elements (mesh resolutions), we can visualize and quantify the impact of mesh resolution on the fidelity of the computed spectra.
#
# We also overlay the same profiles convolved to **R = 70 000** (a realistic high-resolution spectrograph, e.g. HARPS) — at that instrumental resolution most of the mesh-driven jaggedness washes out, so the visible mesh-resolution dependence is much smaller than at the native synthesis resolution.
#
# Line synthesis uses `IntensityLazyZarrInterpolator` on the local NLTE Fe atmosphere grid (`fe_nlte_regular.zarr`), evaluated in the 5000–5004 Å Fe-region window used throughout the paper-results notebooks.

# %%
from spice.models import IcosphereModel
from spice.models.mesh_transform import add_rotation, evaluate_rotation
from spice.spectrum import simulate_observed_flux
from spice.spectrum.lazy_zarr_interpolator import IntensityLazyZarrInterpolator
import jax.numpy as jnp
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
from tqdm import tqdm

# %% [markdown]
# Load the NLTE Fe intensity grid. The interpolator carries its own parameter axes (`teff`, `logg`, `[Fe/H]`, `vmicro`, abundance ratios, plus `mu`); `mu` is consumed internally by the intensity call so the per-element mesh parameter vector only needs the stellar-parameter subset.

# %%
line_interp = IntensityLazyZarrInterpolator(
    '/Users/mjablons/code/spice/data/fe_nlte_regular.zarr',
    params=['teff', 'logg', '[Fe/H]', 'vmicro', '[a/Fe]', '[C/Fe]', '[N/Fe]', '[O/Fe]', '[r/Fe]', '[s/Fe]', 'mu'],
    sparse=True,
)

STELLAR_PARAMS = {'teff': 5777., 'logg': 4.44, '[Fe/H]': 0.0, 'vmicro': 1.0}
# Out:
# [spice] zarr loaded in 2.4 s
# Building sparse grid index...
# Sparse grid index ready.
# [spice] Loading data:   0%|          | 0/3 [00:00<?, ?it/s]
# [spice] Spectral grid loaded in 3.8 s

# %% [markdown]
# Create models at three approximate mesh resolutions using the interpolator's solar-like default parameters.

# %%
params = line_interp.to_parameters(STELLAR_PARAMS)
param_names = line_interp.stellar_parameter_names

models = {}
models[1000]  = IcosphereModel.construct(1000,  1.0, 1.0, params, param_names)
models[5000]  = IcosphereModel.construct(5000,  1.0, 1.0, params, param_names)
models[20000] = IcosphereModel.construct(20000, 1.0, 1.0, params, param_names)
# Out:
# [spice] IcosphereModel constructed in 1.6 s
# [spice] IcosphereModel constructed in 1.6 s
# [spice] IcosphereModel constructed in 1.7 s

# %% [markdown]
# Apply rotation at three equatorial velocities and evaluate the line-of-sight state at one phase.

# %%
from collections import defaultdict

rs = [1000, 5000, 20000]
vs = [20, 50, 100]
models_with_vs = defaultdict(dict)

for r in rs:
    for v in vs:
        models_with_vs[r][v] = add_rotation(models[r], v)

evaluated_models = defaultdict(dict)
for r in rs:
    for v in vs:
        evaluated_models[r][v] = evaluate_rotation(models_with_vs[r][v], 1.)

# %% [markdown]
# Synthesize the Fe-region line profile from the zarr grid in the 5000–5004 Å window (matching `pulsation_lines.ipynb` / `kochukov2017.ipynb`).

# %%
vws = jnp.linspace(5000., 5004., 200)
log_vws = jnp.log10(vws)
line_fluxes = defaultdict(dict)

for r in tqdm(rs, desc="Resolution"):
    for v in tqdm(vs, desc="Velocity", leave=False):
        line_fluxes[r][v] = simulate_observed_flux(
            line_interp.intensity, evaluated_models[r][v], log_vws,
        )
# Out:
# Resolution:   0%|          | 0/3 [00:00<?, ?it/s]/Users/mjablons/anaconda3/envs/astro/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:125: UserWarning: Explicitly requested dtype int64 requested in astype is not available, and will be truncated to dtype int32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/jax-ml/jax#current-gotchas for more.
#   return lax_numpy.astype(self, dtype, copy=copy, device=device)
# Resolution: 100%|██████████| 3/3 [00:35<00:00, 11.71s/it]

# %%
# Native spectral resolution R = lambda / delta_lambda over the synthesized window.
center_wavelength = float((vws[0] + vws[-1]) / 2)
delta_lambda = float(vws[1] - vws[0])
native_resolution = center_wavelength / delta_lambda
print(f"Native spectral resolution (R) = {native_resolution:.0f}")

# Convolve to R = 70 000 (HARPS-like instrumental broadening). FWHM at line centre is
# lambda / R; convert to a Gaussian sigma in pixel units on the uniform `vws` grid.
from scipy.ndimage import gaussian_filter1d

TARGET_R = 70_000
fwhm_lambda = center_wavelength / TARGET_R
sigma_pix = fwhm_lambda / (2.0 * np.sqrt(2.0 * np.log(2.0))) / delta_lambda
print(f"R = {TARGET_R}: FWHM = {fwhm_lambda:.4f} Å  (sigma = {sigma_pix:.2f} pixels)")

line_fluxes_r70k = defaultdict(dict)
for r in rs:
    for v in vs:
        spectrum = np.asarray(line_fluxes[r][v])
        normalized = spectrum[:, 0] / spectrum[:, 1]
        line_fluxes_r70k[r][v] = gaussian_filter1d(normalized, sigma=sigma_pix)
# Out:
# Native spectral resolution (R) = 256102
# R = 70000: FWHM = 0.0715 Å  (sigma = 1.55 pixels)

# %%
# One panel per (resolution, velocity): native synthesis profile vs. the same profile
# convolved to R = 70 000. Mesh-driven differences are obvious at native resolution and
# largely smoothed out at realistic spectrograph resolution.
fig, axs = plt.subplots(nrows=len(rs), ncols=len(vs), figsize=(15, 10),
                        sharex=True, sharey=True, squeeze=False)

for i, r in enumerate(rs):
    for j, v in enumerate(vs):
        ax = axs[i, j]
        spectrum = line_fluxes[r][v]
        ax.plot(vws, spectrum[:, 0] / spectrum[:, 1],
                color='black', linewidth=1,
                label=f'native (R≈{native_resolution:.0f})')
        ax.plot(vws, line_fluxes_r70k[r][v],
                color='magenta', linewidth=3, alpha=0.6,
                label=f'R = {TARGET_R:,}')

        if i == 0:
            ax.set_title(f'v = {v} km/s')
        if j == 0:
            ax.set_ylabel(f'N = {len(models[r].areas)}\nContinuum-normalized intensity')
        if i == len(rs) - 1:
            ax.set_xlabel(r'wavelength [$\AA$]')
            ax.tick_params(axis='x', rotation=45)

axs[-2, 1].legend(loc='lower center', fontsize=12, frameon=False)
plt.tight_layout()

# %%
fig.savefig('mesh_resolution_effects.pdf', bbox_inches='tight', dpi=300)
