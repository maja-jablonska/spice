# %%
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt
from geometry.utils import inside, append_to_last_nan, repeat_last, wrap
from geometry.sutherland_hodgman import compute_intersection, clip

# %%
p1, p2 = jnp.array([0., 1.]), jnp.array([2., 2.])
q1, q2 = jnp.array([1., 1.]), jnp.array([1.5, 3.0])

# %%
i = compute_intersection(p1, p2, q1, q2)
plt.plot([p1[0], p2[0]], [p1[1], p2[1]], color='black')
plt.plot([q1[0], q2[0]], [q1[1], q2[1]], color='black')
plt.scatter(i[0, 0], i[0, 1], color='red', zorder=2)

# %%
plt.plot([p1[0], p2[0]], [p1[1], p2[1]], color='black')

# %%
inside(p1, p2, jnp.array([1., 2.]))
# Out:
# Array(True, dtype=bool)

# %%
t1 = jnp.array([[0., 1.],
                [3., 0.75],
                [2., 3.]],)
t2 = jnp.array([[-1., 0.65],
                [2., 1.],
                [1., 2.]])

t3 = clip(t2, t1)

# %%
t3
# Out:
# Array([[1.       , 2.       ],
#        [0.       , 1.       ],
#        [1.1666666, 0.9027778],
#        [2.       , 1.       ],
#        [2.       , 1.       ],
#        [2.       , 1.       ]], dtype=float32)

# %%
plt.plot(wrap(t1)[:, 0], wrap(t1)[:, 1])
plt.plot(wrap(t2)[:, 0], wrap(t2)[:, 1])
plt.plot(wrap(t3)[:, 0], wrap(t3)[:, 1])

# %%
t1.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 t1.shape
#
# NameError: name 't1' is not defined

# %%
plt.plot(wrap(t1)[:, 0], wrap(t1)[:, 1])
plt.plot(wrap(t2)[:, 0], wrap(t2)[:, 1])
plt.plot(wrap(t3)[:, 0], wrap(t3)[:, 1])
